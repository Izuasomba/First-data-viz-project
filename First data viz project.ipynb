# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/hp/House_Price.csv", header = 0)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x = "n_hot_rooms", y = "price", data = df)

# %%
sns.jointplot(x = "rainfall", y="price", data = df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x = "airport", data = df)
# Out:
# <Axes: xlabel='airport', ylabel='count'>

# %%
sns.countplot(x = "waterbody", data = df)
# Out:
# <Axes: xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x = "bus_ter", data = df)
# Out:
# <Axes: xlabel='bus_ter', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
np.percentile(df.n_hot_rooms,[99]) #gives the 99th percentile as output
# Out:
# array([15.39952])

# %%
uv = np.percentile(df.n_hot_rooms,[99])[0]

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x="age", y="price", data = df)

# %%
df.n_hot_rooms[(df.n_hot_rooms > 3*uv)] = 3*uv
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6768\4019091346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[(df.n_hot_rooms > 3*uv)] = 3*uv

# %%
lv = np.percentile(df.rainfall,[1])[0]

# %%
df.rainfall[(df.rainfall<0.3*lv)]=0.3*lv
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6768\4294583474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rainfall[(df.rainfall<0.3*lv)]=0.3*lv

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.jointplot(x="crime_rate",y="price", data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean()) #fills all the empty columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot(x="crime_rate", y="price", data=df)

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x="crime_rate", y="price", data=df)

# %%
df["avg_dist"]=(df.dist1 + df.dist2 + df.dist3 + df.dist4)/4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del df["dist2"]

# %%
del df["dist3"]

# %%
del df["dist4"]

# %%
del df["bus_ter"]

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856      None        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# ...

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# dist1                     0.251355   -0.587703   -0.706481 -0.768589
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# ...

# %%
del df["parks"]

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  \
# 0       4.98       5.480     11.19200        23    4.0875           0
# 1       9.14       7.332     12.17280        42    4.9675           1
# 2       4.03       7.394     46.19856        38    4.9675           1
# 3       2.94       9.268     11.26720        45    6.0650           0
# 4       5.33       8.824     11.28960        55    6.0625           1
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_None  \
# ...

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(df["room_num"]) #creates our variable "x" and adds our constant

# %%
lm = sn.OLS(df["price"], X).fit() #OLS = ordinary least square; lm is our model name

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Thu, 25 May 2023   Prob (F-statistic):           1.31e-74
# Time:                        00:43:23   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %% [markdown]
# ## linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df["price"]

# %%
x = df[["room_num"]]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# -34.6592431230972 [9.09966966]

# %%
lm2.predict(x)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(data=None, *, x=None, y=None, hue=None, kind='scatter', height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, color=None, palette=None, hue_order=None, hue_norm=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#         Input data structure. Either a long-form collection of vectors that can be
#         assigned to named variables or a wide-form dataset that will be internally
#         reshaped.
# ...

# %%
sns.jointplot(x = df["room_num"], y = df["price"], data = df, kind = "reg")

# %% [markdown]
# ## Multiple linear regression

# %%
X_multi = df.drop("price", axis = 1)

# %%
X_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0    0.006300       32.31     0.538     6.575  65.2   4.35      24.7
# 1    0.026944       37.07     0.469     6.421  78.9   4.99      22.2
# 2    0.026924       37.07     0.469     7.185  61.1   5.03      22.2
# 3    0.031857       32.18     0.458     6.998  45.8   6.21      21.3
# 4    0.066770       32.18     0.458     7.147  54.2   6.16      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  \
# 0       4.98       5.480     11.19200        23    4.0875           0
# 1       9.14       7.332     12.17280        42    4.9675           1
# 2       4.03       7.394     46.19856        38    4.9675           1
# 3       2.94       9.268     11.26720        45    6.0650           0
# 4       5.33       8.824     11.28960        55    6.0625           1
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_None  \
# ...

# %%
y_multi = df["price"]

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2   4.35      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9   4.99      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1   5.03      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8   6.21      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2   6.16      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  \
# 0       4.98       5.480     11.19200        23    4.0875           0
# 1       9.14       7.332     12.17280        42    4.9675           1
# 2       4.03       7.394     46.19856        38    4.9675           1
# 3       2.94       9.268     11.26720        45    6.0650           0
# 4       5.33       8.824     11.28960        55    6.0625           1
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_None  \
# ...

# %%
lm_multi = sn.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     78.91
# Date:                Thu, 25 May 2023   Prob (F-statistic):          3.92e-124
# Time:                        00:43:30   Log-Likelihood:                -1516.6
# No. Observations:                 506   AIC:                             3067.
# Df Residuals:                     489   BIC:                             3139.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
lm3 = LinearRegression()

# %%
lm3.fit(X_multi, y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# -6.108502884274198 [ 9.55435698e-03 -4.08351475e-02 -1.58972727e+01  4.01927967e+00
#  -5.71422718e-03 -2.39028515e-02  1.00698402e+00 -5.77284614e-01
#   3.29123221e-01  9.17823720e-02  1.61232544e-02 -1.19471366e+00
#  -5.65905891e-01  5.65905891e-01  4.42868532e-01 -5.09074617e-01
#   1.78935522e-01 -1.12729438e-01]

# %% [markdown]
# ## Test train split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size=0.2, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_test.shape, y_train.shape)
# Out:
# (404, 18) (102, 18) (102,) (404,)

# %%
 lm_a = LinearRegression()

# %%
lm_a.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(X_test)

# %%
y_train_a = lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_test_a)
# Out:
# 0.5489515243783595

# %%
r2_score(y_train, y_train_a)
# Out:
# 0.7565226016656778

# %% [markdown]
# ## Ridge Regression & Lasso

# %%
#standardize your data

from sklearn import preprocessing

# %%
# created a scalar object that will store scaling info from x variable
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
#Transform X_train into X_train scaler
X_train_s = scaler.transform(X_train)

# %%
#Transform test set
X_test_s = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
lm_r = Ridge(alpha= 0.5)
lm_r.fit(X_train_s, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
r2_score(y_test, lm_r.predict(X_test_s))
# Out:
# 0.5494178373274019

# %%
from sklearn.model_selection import validation_curve

# %%
validation_curve?
# Out:
# Signature:
# validation_curve(
#     estimator,
#     X,
#     y,
#     *,
#     param_name,
#     param_range,
#     groups=None,
#     cv=None,
#     scoring=None,
#     n_jobs=None,
#     pre_dispatch='all',
#     verbose=0,
#     error_score=nan,
#     fit_params=None,
# )
# Docstring:
# Validation curve.
#
# Determine training and test scores for varying parameter values.
#
# Compute scores for an estimator with different values of a specified
# parameter. This is similar to grid search with one parameter. However, this
# will also compute training scores and is merely a utility for plotting the
# results.
#
# Read more in the :ref:`User Guide <validation_curve>`.
#
# Parameters
# ----------
# estimator : object type that implements the "fit" and "predict" methods
#     An object of that type which is cloned for each validation.
#
# X : array-like of shape (n_samples, n_features)
#     Training vector, where `n_samples` is the number of samples and
# ...

# %%
param_range = np.logspace(-2,8,100)

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(
    Ridge(),
    X_train,
    y_train,
    param_name="alpha",
    param_range = param_range,
    scoring="r2",
)

# %%
print(train_scores)
print(test_scores)
# Out:
# [[0.7496645  0.7626627  0.75357157 0.78236265 0.74605881]
#  [0.74966386 0.76266224 0.75357101 0.78236218 0.74605818]
#  [0.74966284 0.76266151 0.75357013 0.78236143 0.7460572 ]
#  [0.74966123 0.76266037 0.75356874 0.78236025 0.74605564]
#  [0.74965872 0.76265858 0.75356657 0.78235841 0.7460532 ]
#  [0.74965478 0.76265578 0.75356319 0.78235554 0.74604939]
#  [0.74964867 0.76265146 0.75355795 0.78235107 0.74604347]
#  [0.74963921 0.7626448  0.75354988 0.78234419 0.74603433]
#  [0.74962468 0.76263463 0.75353754 0.78233366 0.74602031]
#  [0.74960259 0.76261927 0.75351889 0.78231771 0.74599902]
#  [0.74956933 0.76259634 0.75349102 0.78229382 0.74596705]
#  [0.74951994 0.76256261 0.75345001 0.78225856 0.74591967]
#  [0.74944775 0.7625139  0.75339068 0.7822074  0.74585063]
#  [0.74934422 0.76244499 0.75330665 0.78213464 0.74575196]
#  [0.749199   0.76234986 0.75319046 0.78203361 0.74561411]
#  [0.74900052 0.76222214 0.7530342  0.78189708 0.74542655]
# ...

# %%
train_mean = np.mean(train_scores, axis =1 )

# %%
test_mean = np.mean(train_scores, axis =1 )

# %%
train_mean
# Out:
# array([0.75886405, 0.75886349, 0.75886262, 0.75886125, 0.7588591 ,
#        0.75885574, 0.75885052, 0.75884248, 0.75883017, 0.75881149,
#        0.75878351, 0.75874216, 0.75868207, 0.75859649, 0.75847741,
#        0.7583161 , 0.7581041 , 0.75783464, 0.75750431, 0.75711446,
#        0.75667192, 0.75618858, 0.75567977, 0.75516181, 0.75464927,
#        0.75415255, 0.75367598, 0.75321665, 0.75276357, 0.75229701,
#        0.75178783, 0.75119684, 0.75047462, 0.74956255, 0.74839562,
#        0.746908  , 0.74504103, 0.74275274, 0.74002644, 0.7368754 ,
#        0.7333412 , 0.72948464, 0.72537072, 0.72105079, 0.71654603,
#        0.71183608, 0.70685535, 0.70149811, 0.69563127, 0.68911107,
#        0.68179811, 0.67356393, 0.66428471, 0.65382234, 0.6420001 ,
#        0.62858508, 0.61329099, 0.59581041, 0.57587701, 0.55334638,
#        0.52827432, 0.50096571, 0.47197217, 0.44203102, 0.41195797,
#        0.38252166, 0.35433251, 0.32777027, 0.30296088, 0.27979993,
# ...

# %%
max(test_mean)
# Out:
# 0.7588640493048897

# %%
sns.jointplot(x = np.log(param_range), y = test_mean)

# %%
np.where(test_mean == max(test_mean))
# Out:
# (array([0], dtype=int64),)

# %%
param_range[0]
# Out:
# 0.01

# %%
lm_r_best = Ridge(alpha = param_range[0])

# %%
lm_r_best.fit(X_train_s, y_train)
# Out:
# Ridge(alpha=0.01)

# %%
r2_score(y_test, lm_r_best.predict(X_test_s))
# Out:
# 0.5489789818483402

# %%
r2_score(y_train, lm_r_best.predict(X_train_s))
# Out:
# 0.7565224966447843

# %%
from sklearn.linear_model import Lasso

# %%
lm_l = Lasso(alpha = 0.4)

# %% [markdown]
# ## K-Nearest neighbours

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_s= scaler.transform(X_train)
